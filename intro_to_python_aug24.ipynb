# %% [markdown]
# <a href="https://colab.research.google.com/github/sandarnaing/tutorial/blob/main/intro_to_python_aug24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"Hello World"
# Out:
# 'Hello World'

# %% [markdown]
# Basics of Python

# %%
print("Hello colab!")
# Out:
# Hello colab!

# %%
# Variables

message = 'Hello Colab!'

# %%
message
# Out:
# 'Hello Colab!'

# %%
# Datatypes

a = 5

# %%
a
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
b = 5.0

# %%
type(b)
# Out:
# float

# %%
letters = "ABACBS"

# %%
type(letters)
# Out:
# str

# %%
some_words = "Python3 strings are Unicode (UTF-8) ❤❤❤ 😸 蛇"

# %%
type(some_words)
# Out:
# str

# %%
some_words
# Out:
# 'Python3 strings are Unicode (UTF-8) ❤❤❤ 😸 蛇'

# %%
# Operators - + - * / % **

2 + 2
# Out:
# 4

# %%
6 * 7
# Out:
# 42

# %%
2 ** 16
# Out:
# 65536

# %%
13 % 5 # remainder
# Out:
# 3

# %%
a = 5
a + 1
# Out:
# 6

# %%
b = 5.0
b + 1
# Out:
# 6.0

# %%
a + b
# Out:
# 10.0

# %%
some_words = "I'm a string"

# %%
type(some_words)
# Out:
# str

# %%
a + some_words
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-5677ebf6b737> in <cell line: 1>()
# ----> 1 a + some_words
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
str(a) + some_words
# Out:
# "5I'm a string"

# %%
str(a)
# Out:
# '5'

# %%
a
# Out:
# 5

# %%
str(a) + ' ' + some_words
# Out:
# "5 I'm a string"

# %%
# shorthand

a = a + 1
a
# Out:
# 9

# %%
a += 1 #same as a = a + 1

# %%
a
# Out:
# 8

# %%
# Boolean Operators- > < >= <= != ==
3 > 4
# Out:
# False

# %%
3 >= 4
# Out:
# False

# %%
4 >= 4
# Out:
# True

# %%
True and True
# Out:
# True

# %%
False and True
# Out:
# False

# %%
True or False
# Out:
# True

# %%
print(True or True)
print(False or False)
# Out:
# True
# False

# %%
a > b
# Out:
# True

# %%
# LISTS and Sequence types

# %%
numbers = [2,4,6,8,10]
numbers
# Out:
# [2, 4, 6, 8, 10]

# %%
type(numbers)
# Out:
# list

# %%
len(numbers)
# Out:
# 5

# %%
mixed_list = ["asdf", 2, 3.142, numbers, ['a','b','c']]
mixed_list
# Out:
# ['asdf', 2, 3.142, [2, 4, 6, 8, 10], ['a', 'b', 'c']]

# %%
# indexing - list_name[index/position] - indexing starts at 0
mixed_list[0]
# Out:
# 'asdf'

# %%
mixed_list[3]
# Out:
# [2, 4, 6, 8, 10]

# %%
numbers
# Out:
# [2, 4, 6, 8, 10]

# %%
numbers[3]
# Out:
# 8

# %%
numbers[3] = numbers[3] * 100
numbers
# Out:
# [2, 4, 6, 800, 10]

# %%
numbers.append(12)
numbers
# Out:
# [2, 4, 6, 800, 10, 12]

# %%
len(numbers)
# Out:
# 6

# %%
numbers.extend([14,16,18])
numbers
# Out:
# [2, 4, 6, 800, 10, 12, 14, 16, 18]

# %%
# Loops

for num in numbers:
  print(num) # --> Indentation
# Out:
# 2
# 4
# 6
# 800
# 10
# 12
# 14
# 16
# 18

# %%
# Tuples - ()

# %%
tuples_are_immutable = ("bar", 100, 200, "foo")
tuples_are_immutable
# Out:
# ('bar', 100, 200, 'foo')

# %%
tuples_are_immutable[0] # --> indexing
# Out:
# 'bar'

# %%
tuples_are_immutable[1] = 666
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-c91965b0815a> in <cell line: 1>()
# ----> 1 tuples_are_immutable[1] = 666
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Dictionaries - {key:value}

# %%
pairs = {'Apple':1, 'Orange':2, 'Pear':4}
pairs
# Out:
# {'Apple': 1, 'Orange': 2, 'Pear': 4}

# %%
pairs['Orange']
# Out:
# 2

# %%
pairs = {'Apple':1, 'Orange':2, 'Pear':4, 'Orange':5}
pairs
# Out:
# {'Apple': 1, 'Orange': 5, 'Pear': 4}

# %%
pairs['Pear']
# Out:
# 4

# %%
pairs.keys()
# Out:
# dict_keys(['Apple', 'Orange', 'Pear'])

# %%
pairs.values()
# Out:
# dict_values([1, 5, 4])

# %%
pairs.items()
# Out:
# dict_items([('Apple', 1), ('Orange', 5), ('Pear', 4)])

# %%
len(pairs)
# Out:
# 3

# %%
dict_of_dicts = {'first': {1:2, 2: 4, 4: 8, 8: 16}, 'second': {'a': 2.2, 'b': 4.4}}
dict_of_dicts
# Out:
# {'first': {1: 2, 2: 4, 4: 8, 8: 16}, 'second': {'a': 2.2, 'b': 4.4}}

# %%
dict_of_dicts['first']
# Out:
# {1: 2, 2: 4, 4: 8, 8: 16}

# %%
jam_ratings = {'Plum': 6, 'Apricot': 2, 'Strawberry': 8}

# %%
jam_ratings['Apricot'] = 9

# %%
jam_ratings
# Out:
# {'Plum': 6, 'Apricot': 9, 'Strawberry': 8}

# %%
import urllib.request
url = 'https://monashdatafluency.github.io/python-workshop-base/modules/data/surveys.csv'
urllib.request.urlretrieve(url, 'surveys.csv')
# Out:
# ('surveys.csv', <http.client.HTTPMessage at 0x7ec188b807f0>)

# %%
('surveys.csv',)
# Out:
# ('surveys.csv',)

# %%
# !pip install pandas matplotlib

# %%
import pandas as pd

# %%
pd.read_csv("surveys.csv")
# Out:
#        record_id  month  day  year  site_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
surveys_df = pd.read_csv("surveys.csv")

# %%
surveys_df
# Out:
#        record_id  month  day  year  site_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
type(surveys_df)
# Out:
# pandas.core.frame.DataFrame

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# site_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'site_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
surveys_df.shape
# Out:
# (35549, 9)

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  site_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
surveys_df.tail()
# Out:
#        record_id  month  day  year  site_id species_id  sex  hindfoot_length  \
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN

# %%
surveys_df.head(15)
# Out:
#     record_id  month  day  year  site_id species_id  sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL    M             32.0
# 1           2      7   16  1977        3         NL    M             33.0
# 2           3      7   16  1977        2         DM    F             37.0
# 3           4      7   16  1977        7         DM    M             36.0
# 4           5      7   16  1977        3         DM    M             35.0
# 5           6      7   16  1977        1         PF    M             14.0
# 6           7      7   16  1977        2         PE    F              NaN
# 7           8      7   16  1977        1         DM    M             37.0
# 8           9      7   16  1977        1         DM    F             34.0
# 9          10      7   16  1977        6         PF    F             20.0
# 10         11      7   16  1977        5         DS    F             53.0
# 11         12      7   16  1977        7         DM    M             38.0
# ...

# %%
surveys_df.iloc[50]
# Out:
# record_id            51
# month                 7
# day                  18
# year               1977
# site_id              21
# species_id           DM
# sex                   F
# hindfoot_length    36.0
# weight              NaN
# Name: 50, dtype: object

# %%
surveys_df['species_id']
# Out:
# 0         NL
# 1         NL
# 2         DM
# 3         DM
# 4         DM
#         ...
# 35544     AH
# 35545     AH
# 35546     RM
# 35547     DO
# 35548    NaN
# Name: species_id, Length: 35549, dtype: object

# %%
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
pd.unique(surveys_df['site_id'])
# Out:
# array([ 2,  3,  7,  1,  6,  5,  8,  4, 11, 14, 15, 13,  9, 10, 17, 16, 20,
#        23, 18, 21, 22, 19, 12, 24])

# %%
len(pd.unique(surveys_df['site_id']))
# Out:
# 24

# %%
surveys_df['site_id'].nunique()
# Out:
# 24

# %%
# Groups in python

surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
surveys_df['weight'].min()
# Out:
# 4.0

# %%
surveys_df['weight'].max()
# Out:
# 280.0

# %%
surveys_df['weight'].std()
# Out:
# 36.63125947458358

# %%
grouped_data = surveys_df.groupby('sex')

# %%
grouped_data.describe()
# Out:
#     record_id                                                               \
#         count          mean           std  min      25%      50%       75%
# sex
# F     15690.0  18036.412046  10423.089000  3.0  8917.50  18075.5  27250.00
# M     17348.0  17754.835601  10132.203323  1.0  8969.75  17727.5  26454.25
#
#                 month            ... hindfoot_length         weight  \
#          max    count      mean  ...             75%   max    count
# sex                              ...
# F    35547.0  15690.0  6.583047  ...            36.0  64.0  15303.0
# M    35548.0  17348.0  6.392668  ...            36.0  58.0  16879.0
#
#
#           mean        std  min   25%   50%   75%    max
# sex
# F    42.170555  36.847958  4.0  20.0  34.0  46.0  274.0
# M    42.995379  36.184981  4.0  20.0  39.0  49.0  280.0
#
# [2 rows x 56 columns]

# %%
grouped_data.mean(numeric_only=True)
# Out:
#         record_id     month        day         year    site_id  \
# sex
# F    18036.412046  6.583047  16.007138  1990.644997  11.440854
# M    17754.835601  6.392668  16.184286  1990.480401  11.098282
#
#      hindfoot_length     weight
# sex
# F          28.836780  42.170555
# M          29.709578  42.995379

# %%
grouped_data2 = surveys_df.groupby(['site_id', 'sex'])

# %%
grouped_data2.describe()
# Out:
#             record_id                                                         \
#                 count          mean           std     min       25%      50%
# site_id sex
# 1       F       848.0  18390.384434  10469.790852     9.0   8783.50  19182.5
#         M      1095.0  17197.740639   9911.570595     6.0   8638.00  17043.0
# 2       F       970.0  17714.753608  10300.015076     3.0   9580.25  18104.5
#         M      1144.0  18085.458042  10555.331260     1.0   8653.00  19024.5
# 3       F       893.0  19888.783875   9352.010884    17.0  12963.00  20051.0
#         M       840.0  20226.767857   9680.405281     2.0  13184.25  20904.5
# 4       F       872.0  17489.205275  10314.252887    16.0   8733.00  17441.5
#         M      1030.0  18493.841748   9808.465995   195.0  10845.00  18666.5
# 5       F       527.0  12280.793169   8296.352658    11.0   5445.50  10916.0
#         M       586.0  12798.426621   8457.974266    98.0   5994.75  11203.0
# ...

# %%
grouped_data2.mean(numeric_only=True)
# Out:
#                 record_id     month        day         year  hindfoot_length  \
# site_id sex
# 1       F    18390.384434  6.597877  15.338443  1990.933962        31.733911
#         M    17197.740639  6.121461  15.905936  1990.091324        34.302770
# 2       F    17714.753608  6.426804  16.288660  1990.449485        30.161220
#         M    18085.458042  6.340035  15.440559  1990.756119        30.353760
# 3       F    19888.783875  6.604703  16.161254  1992.013438        23.774044
#         M    20226.767857  6.271429  16.450000  1992.275000        23.833744
# 4       F    17489.205275  6.442661  15.746560  1990.235092        33.249102
#         M    18493.841748  6.430097  16.507767  1991.000971        34.097959
# 5       F    12280.793169  6.142315  15.722960  1986.485769        28.921844
#         M    12798.426621  6.194539  15.703072  1986.817406        29.694794
# 6       F    19406.503392  6.628223  16.313433  1991.579376        26.981322
# ...

# %%
grouped_data.count()['record_id']
# Out:
# sex
# F    15690
# M    17348
# Name: record_id, dtype: int64

# %%
by_site = surveys_df.groupby('site_id')

# %%
by_site['weight'].describe()
# Out:
#           count       mean        std  min   25%   50%   75%    max
# site_id
# 1        1903.0  51.822911  38.176670  4.0  30.0  44.0  53.0  231.0
# 2        2074.0  52.251688  46.503602  5.0  24.0  41.0  50.0  278.0
# 3        1710.0  32.654386  35.641630  4.0  14.0  23.0  36.0  250.0
# 4        1866.0  47.928189  32.886598  4.0  30.0  43.0  50.0  200.0
# 5        1092.0  40.947802  34.086616  5.0  21.0  37.0  48.0  248.0
# 6        1463.0  36.738893  30.648310  5.0  18.0  30.0  45.0  243.0
# 7         638.0  20.663009  21.315325  4.0  11.0  17.0  23.0  235.0
# 8        1781.0  47.758001  33.192194  5.0  26.0  44.0  51.0  178.0
# 9        1811.0  51.432358  33.724726  6.0  36.0  45.0  50.0  275.0
# 10        279.0  18.541219  20.290806  4.0  10.0  12.0  21.0  237.0
# 11       1793.0  43.451757  28.975514  5.0  26.0  42.0  48.0  212.0
# 12       2219.0  49.496169  41.630035  6.0  26.0  42.0  50.0  280.0
# 13       1371.0  40.445660  34.042767  5.0  20.5  33.0  45.0  241.0
# ...

# %%
# count number of samples by species

surveys_df.groupby('species_id')['record_id'].count()
# Out:
# species_id
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
surveys_df.groupby('species_id')['record_id'].count()['AB']
# Out:
# 303

# %%
species_count = surveys_df.groupby('species_id')['record_id'].count()
print (species_count)
# Out:
# species_id
# AB      303
# AH      437
# AS        2
# BA       46
# CB       50
# CM       13
# CQ       16
# CS        1
# CT        1
# CU        1
# CV        1
# DM    10596
# DO     3027
# DS     2504
# DX       40
# NL     1252
# OL     1006
# OT     2249
# OX       12
# PB     2891
# PC       39
# PE     1299
# PF     1597
# PG        8
# PH       32
# PI        9
# PL       36
# PM      899
# PP     3123
# PU        5
# PX        6
# RF       75
# RM     2609
# RO        8
# RX        2
# SA       75
# SC        1
# SF       43
# SH      147
# SO       43
# SS      248
# ST        1
# SU        5
# UL        4
# UP        8
# UR       10
# US        4
# ZL        2
# Name: record_id, dtype: int64

# %%
surveys_df['weight'] * 2
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 35544      NaN
# 35545      NaN
# 35546     28.0
# 35547    102.0
# 35548      NaN
# Name: weight, Length: 35549, dtype: float64

# %%
# plotting

# %matplotlib inline

# %%
species_count.plot(kind = 'bar')
# Out:
# <Axes: xlabel='species_id'>

# %%
# plot how many animals are captured in each group

# %%
total_count = surveys_df.groupby('site_id')['record_id'].nunique()

# %%
total_count
# Out:
# site_id
# 1     1995
# 2     2194
# 3     1828
# 4     1969
# 5     1194
# 6     1582
# 7      816
# 8     1891
# 9     1936
# 10     469
# 11    1918
# 12    2365
# 13    1538
# 14    1885
# 15    1069
# 16     646
# 17    2039
# 18    1445
# 19    1189
# 20    1390
# 21    1173
# 22    1399
# 23     571
# 24    1048
# Name: record_id, dtype: int64

# %%
total_count.plot(kind = 'bar')
# Out:
# <Axes: xlabel='site_id'>

# %%
surveys_df
# Out:
#        record_id  month  day  year  site_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
x = 5

# %%
x > 5
# Out:
# False

# %%
x == 5
# Out:
# True

# %%
#value == 'NaN'

# %%
surveys_df.isnull().sum()
# Out:
# record_id             0
# month                 0
# day                   0
# year                  0
# site_id               0
# species_id          763
# sex                2511
# hindfoot_length    4111
# weight             3266
# dtype: int64

# %%
surveys_df.isnull().sum().sum()
# Out:
# 10651

# %%
# logical index
# surveys_df[condition_one_dim]

# %%
surveys_df
# Out:
#        record_id  month  day  year  site_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
surveys_df.isnull().any(axis = 1)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 35544     True
# 35545     True
# 35546    False
# 35547    False
# 35548     True
# Length: 35549, dtype: bool

# %%
surveys_df[surveys_df.isnull().any(axis = 1)]
# Out:
#        record_id  month  day  year  site_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35530      35531     12   31  2002       13         PB    F             27.0
# 35543      35544     12   31  2002       15         US  NaN              NaN
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
cleaned = surveys_df[~surveys_df.isnull().any(axis = 1)] # ! ~

# %%
cleaned
# Out:
#        record_id  month  day  year  site_id species_id sex  hindfoot_length  \
# 62            63      8   19  1977        3         DM   M             35.0
# 63            64      8   19  1977        7         DM   M             37.0
# 64            65      8   19  1977        4         DM   F             34.0
# 65            66      8   19  1977        4         DM   F             35.0
# 66            67      8   19  1977        7         DM   M             35.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 35540      35541     12   31  2002       15         PB   F             24.0
# 35541      35542     12   31  2002       15         PB   F             26.0
# 35542      35543     12   31  2002       15         PB   F             27.0
# 35546      35547     12   31  2002       10         RM   F             15.0
# 35547      35548     12   31  2002        7         DO   M             36.0
#
#        weight
# 62       40.0
# 63       48.0
# ...

# %%
surveys_df # null, NA, -9999, nan
# Out:
#        record_id  month  day  year  site_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
surveys_df.weight.mean() # with missing values
# Out:
# 42.672428212991356

# %%
df = surveys_df.copy()

# %%
df.weight = df['weight'].fillna (0)

# %%
df
# Out:
#        record_id  month  day  year  site_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         0.0
# ...

# %%
df.weight.mean() # with no missing values
# Out:
# 38.751976145601844

# %%
# replace NaN with average weight

surveys_df.weight.mean()
# Out:
# 42.672428212991356

# %%
surveys_df
# Out:
#        record_id  month  day  year  site_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# ...

# %%
surveys_df.weight = surveys_df.weight.fillna (surveys_df.weight.mean())

# %%
surveys_df
# Out:
#        record_id  month  day  year  site_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#           weight
# 0      42.672428
# ...

# %%
surveys_df.weight.mean()
# Out:
# 42.672428212991356

# %%
cleaned.weight.mean()
# Out:
# 41.791367844569045

# %%
cleaned.to_csv("cleaned_surveys.csv", index = False)

# %%
# drop all the values
# substitute some values

# %%
surveys_df.dropna()
# Out:
#        record_id  month  day  year  site_id species_id sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL   M             32.0
# 1              2      7   16  1977        3         NL   M             33.0
# 2              3      7   16  1977        2         DM   F             37.0
# 3              4      7   16  1977        7         DM   M             36.0
# 4              5      7   16  1977        3         DM   M             35.0
# ...          ...    ...  ...   ...      ...        ...  ..              ...
# 35540      35541     12   31  2002       15         PB   F             24.0
# 35541      35542     12   31  2002       15         PB   F             26.0
# 35542      35543     12   31  2002       15         PB   F             27.0
# 35546      35547     12   31  2002       10         RM   F             15.0
# 35547      35548     12   31  2002        7         DO   M             36.0
#
#           weight
# 0      42.672428
# 1      42.672428
# ...
